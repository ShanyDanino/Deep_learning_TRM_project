# %%
from google.colab import userdata
import os
import sys

# 1. Get the token from Secrets (securely)
token = userdata.get('GITHUB_TOKEN')

# 2. Define repository details
username = "ShanyDanino"
repo_name = "Deep_learning_TRM_project"

# 3. Construct the authenticated URL
# This keeps the token out of your printed code/logs
repo_url = f"https://{token}@github.com/{username}/{repo_name}.git"

# 4. Clone the repository
if not os.path.exists("my_repo"):
    # !git clone {repo_url} my_repo
else:
    print("Repository already exists.")

# %%
# %%bash
#
# # Push
# # cd my_repo
# # git add /content/my_repo/tiny_recursive_models/src/tiny_recursive_models/models/architectures/transformers_baseline.py
# # git commit -m "Test for overwritten file"
# # git push origin main

# %%
# Set your API key in the environment
# Get your key from: https://wandb.ai/authorize
os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')

# Install to system (Force version compatibility)
# !uv pip install --system -e /content/my_repo/tiny_recursive_models
# !uv pip install --system torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Set the path so your custom 'our.py' is found
os.environ["PYTHONPATH"] = "/content/my_repo/tiny_recursive_models/src"
sys.path.append("/content/my_repo/tiny_recursive_models")
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 45 packages in 808ms
# Prepared 5 packages in 2.08s
# Installed 5 packages in 8ms
#  + argdantic==1.3.3
#  + coolname==2.2.0
#  + hydra-core==1.3.2
#  + ninja==1.13.0
#  + tiny-recursive-models==0.1.0 (from file:///content/my_repo/tiny_recursive_models)
# Using Python 3.12.12 environment at: /usr
# Audited 3 packages in 83ms

# %%
# Pulling dataset files
GITHUB_DATASET_REPO_URL = "https://github.com/josebambu/NonoDataset.git"
dataset_repo_name = GITHUB_DATASET_REPO_URL.split("/")[-1].replace(".git", "")

if not os.path.exists(dataset_repo_name):
    print(f"Cloning {dataset_repo_name}...")
    # !git clone $GITHUB_DATASET_REPO_URL
else:
    print(f"Repository '{dataset_repo_name}' already exists. Skipping clone.")
# Out:
# Cloning NonoDataset...
# Cloning into 'NonoDataset'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 44 (delta 0), reused 3 (delta 0), pack-reused 41 (from 1)
# Receiving objects: 100% (44/44), 359.71 MiB | 32.70 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (36/36), done.

# %%
"""
import os
import shutil

def rm_dir(directory_path):
  if os.path.exists(directory_path):
      try:
          shutil.rmtree(directory_path)
          print(f"Directory '{directory_path}' and all its contents removed.")
      except OSError as e:
          print(f"Error: {e.strerror}")
  else:
    print("not found")
# !cd my_repo/tiny_recursive_models/
print(os.path.join("sampled_dataset"))
rm_dir(os.path.join("sampled_dataset"))
# !readlink -f sampled_dataset
"""
# Out:
# '\nimport os\nimport shutil\n\ndef rm_dir(directory_path):\n  if os.path.exists(directory_path):\n      try:\n          shutil.rmtree(directory_path)\n          print(f"Directory \'{directory_path}\' and all its contents removed.")\n      except OSError as e:\n          print(f"Error: {e.strerror}")\n  else:\n    print("not found")\n!cd my_repo/tiny_recursive_models/\nprint(os.path.join("sampled_dataset"))\nrm_dir(os.path.join("sampled_dataset"))\n!readlink -f sampled_dataset\n'

# %%
# %%bash
#
# cd my_repo/tiny_recursive_models/
# chmod +x speedrun.sh
# ./speedrun.sh 5 1000 "../../NonoDataset" "data/nonogram_dataset"
# Out:
# ERROR: No GPUs detected. This training requires at least 1 GPU.
# Please ensure CUDA and nvidia-smi are properly installed.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-3109939163.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '\ncd my_repo/tiny_recursive_models/\nchmod +x speedrun.sh\n./speedrun.sh 5 1000 "../../NonoDataset" "data/nonogram_dataset"\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\ncd my_repo/tiny_recursive_models/\nchmod +x speedrun.sh\n./speedrun.sh 5 1000 "../../NonoDataset" "data/nonogram_dataset"\n'' returned non-zero exit status 1.
